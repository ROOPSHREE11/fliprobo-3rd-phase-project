# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import scipy as sp
import warnings
import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\ROOPSHREE\Downloads\Glass Identification.csv")

# %%
df
# Out:
#       ID       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  \
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type of Glass
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# ...

# %%
df.head()
# Out:
#    ID       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type of Glass
# 0   1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0              1
# 1   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0              1
# 2   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0              1
# 3   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0              1
# 4   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             214 non-null    int64
#  1   RI             214 non-null    float64
#  2   Na             214 non-null    float64
#  3   Mg             214 non-null    float64
#  4   Al             214 non-null    float64
#  5   Si             214 non-null    float64
#  6   K              214 non-null    float64
#  7   Ca             214 non-null    float64
#  8   Ba             214 non-null    float64
#  9   Fe             214 non-null    float64
#  10  Type of Glass  214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
df.isnull().sum()
# Out:
# ID               0
# RI               0
# Na               0
# Mg               0
# Al               0
# Si               0
# K                0
# Ca               0
# Ba               0
# Fe               0
# Type of Glass    0
# dtype: int64

# %%
df.shape
# Out:
# (214, 11)

# %%
df.value_counts()
# Out:
# ID   RI       Na     Mg    Al    Si     K     Ca    Ba    Fe    Type of Glass
# 1    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00  1                1
# 135  1.51811  13.33  3.85  1.25  72.78  0.52  8.12  0.00  0.00  2                1
# 137  1.51806  13.00  3.80  1.08  73.07  0.56  8.38  0.00  0.12  2                1
# 138  1.51711  12.89  3.62  1.57  72.96  0.61  8.11  0.00  0.00  2                1
# 139  1.51674  12.79  3.52  1.54  73.36  0.66  7.90  0.00  0.00  2                1
#                                                                                 ..
# 75   1.51596  13.02  3.56  1.54  73.11  0.72  7.90  0.00  0.00  2                1
# 76   1.51590  13.02  3.58  1.51  73.12  0.69  7.96  0.00  0.00  2                1
# 77   1.51645  13.44  3.61  1.54  72.39  0.66  8.03  0.00  0.00  2                1
# 78   1.51627  13.00  3.58  1.54  72.83  0.61  8.04  0.00  0.00  2                1
# ...

# %%
df.columns
# Out:
# Index(['ID', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe',
#        'Type of Glass'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                 int64
# RI               float64
# Na               float64
# Mg               float64
# Al               float64
# Si               float64
# K                float64
# Ca               float64
# Ba               float64
# Fe               float64
# Type of Glass      int64
# dtype: object

# %%
df.isnull().any()
# Out:
# ID               False
# RI               False
# Na               False
# Mg               False
# Al               False
# Si               False
# K                False
# Ca               False
# Ba               False
# Fe               False
# Type of Glass    False
# dtype: bool

# %%
df["Type of Glass"].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type of Glass, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.hist(figsize=(20,14))
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot = True)
# Out:
# <Axes: >

# %%
plt.style.use("ggplot")
fig,ax = plt.subplots(3,1, figsize=(12,14))

sns.histplot(x = df["RI"], kde=True,ax=ax[0], color="blueviolet");
ax[0].set_xlabel("RI",fontsize=15);

sns.histplot(x = df["Na"], kde=True,ax=ax[1], color="green");
ax[1].set_xlabel("Na",fontsize=15);

sns.histplot(x = df["Mg"], kde=True,ax=ax[2], color="teal");
ax[2].set_xlabel("Mg",fontsize=15);

# %%
plt.style.use("ggplot")
fig,ax = plt.subplots(3,1, figsize=(12,14))

sns.histplot(x = df["Al"], kde=True,ax=ax[0], color="purple");
ax[0].set_xlabel("Al",fontsize=15);

sns.histplot(x = df["Si"], kde=True,ax=ax[1], color="blue");
ax[1].set_xlabel("Si",fontsize=15);

sns.histplot(x = df["K"], kde=True,ax=ax[2], color="fuchsia");
ax[2].set_xlabel("K",fontsize=15);

# %%
plt.style.use("ggplot")
fig,ax = plt.subplots(3,1, figsize=(12,14))

sns.histplot(x = df["Ca"], kde=True,ax=ax[0], color="cadetblue");
ax[0].set_xlabel("Ca",fontsize=15);

sns.histplot(x = df["Ba"], kde=True,ax=ax[1], color="purple");
ax[1].set_xlabel("Ba",fontsize=15);

sns.histplot(x = df["Fe"], kde=True,ax=ax[2], color="indigo");
ax[2].set_xlabel("Fe",fontsize=15);

# %%
plt.style.use("ggplot")
fig,ax = plt.subplots(3,1, figsize=(12,14))

sns.scatterplot(x=df['Na'],y = df['RI'],hue = df["Type of Glass"],palette='viridis',legend=True,ax=ax[0])
ax[0].set_xlabel("Sodium(Na)",fontsize=15);

sns.scatterplot(x=df['Mg'],y = df['RI'],hue = df["Type of Glass"],palette='spring_r',legend=True,ax=ax[1])
ax[1].set_xlabel("Magnesium(Mg)",fontsize=15);

sns.scatterplot(x=df['Al'],y = df['RI'],hue = df["Type of Glass"],palette='flare_r',legend=True,ax=ax[2])
ax[2].set_xlabel("Almunium(Al)",fontsize=15);

sns.scatterplot(x=df['Fe'],y = df['RI'],hue = df["Type of Glass"],palette='nipy_spectral_r',legend=True,ax=ax[3])
ax[3].set_xlabel("Iron(Fe)",fontsize=15);
# Out:
# ----------------------------------------------------------------
# IndexError                     Traceback (most recent call last)
# Cell In[18], line 13
#      10 sns.scatterplot(x=df['Al'],y = df['RI'],hue = df["Type of Glass"],palette='flare_r',legend=True,ax=ax[2])
#      11 ax[2].set_xlabel("Almunium(Al)",fontsize=15);
# ---> 13 sns.scatterplot(x=df['Fe'],y = df['RI'],hue = df["Type of Glass"],palette='nipy_spectral_r',legend=True,ax=ax[3])
#      14 ax[3].set_xlabel("Iron(Fe)",fontsize=15)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %% [markdown]
# # Splitting The Data Into Training And Testing Datasets

# %%
x = df.drop("Type of Glass",axis = 1)
x.head()
# Out:
#    ID       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0   1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0

# %%
y = df["Type of Glass"]
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Type of Glass, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
len(x_train),len(x_test)
# Out:
# (149, 65)

# %% [markdown]
# # Model Building

# %% [markdown]
# 1.Linear Regression

# %%
from sklearn.linear_model import LinearRegression
np.random.seed(42)
lr =  LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegressionscore = lr.score(x_test,y_test)
print("Accuracy obtained by Linear Regression model:",LinearRegressionscore*100)
# Out:
# Accuracy obtained by Linear Regression model: 89.53041655688513

# %% [markdown]
# 2. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
np.random.seed(42)
dtree =  DecisionTreeClassifier(max_depth = 6, random_state = 123, criterion = 'entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
DecisionTreeClassifierscore=dtree.score(x_test,y_test)
print("Accuracy obtained by Decision Tree Classifier model:",DecisionTreeClassifierscore*100)
# Out:
# Accuracy obtained by Decision Tree Classifier model: 96.92307692307692

# %% [markdown]
# 3.Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
np.random.seed(42)
rfc = RandomForestClassifier(n_estimators = 100)
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
RandomForestClassifierscore = rfc.score(x_test,y_test)
print("Accuracy obtained by  RandomForestClassifier model:", RandomForestClassifierscore*100)
# Out:
# Accuracy obtained by  RandomForestClassifier model: 98.46153846153847

# %% [markdown]
# 4. K Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
np.random.seed(42)
knn = KNeighborsClassifier(4)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
KNeighborsClassifierscore = knn.score(x_test,y_test)
print("Accuracy obtained by KNeighborsClassifier model:",KNeighborsClassifierscore*100)
# Out:
# Accuracy obtained by KNeighborsClassifier model: 95.38461538461539

# %%
y_pred = knn.predict(x_test)
df = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
df
# Out:
#      Actual  Predicted
# 9         1          1
# 197       7          7
# 66        1          1
# 191       7          7
# 117       2          2
# ..      ...        ...
# 5         1          1
# 135       2          2
# 56        1          1
# 199       7          7
# 173       5          5
#
# [65 rows x 2 columns]

# %%
x = ["K Neighbors Classifiers",
   " Random Forest Classifier",
   "Decision Tree Classifier",
   "Linear Regression"]

y = [KNeighborsClassifierscore,
    RandomForestClassifierscore,
    DecisionTreeClassifierscore,
    LinearRegressionscore]

plt.style.use("seaborn")
fig,ax = plt.subplots(figsize =(12,10))
sns.barplot(x=x,y=y,palette = "colorblind");
plt.ylabel("Model Accuracy")
plt.xticks(rotation = 40)
plt.title("Model Comparison - Model Accuracy",fontsize=15,y = 1.03)
# Out:
# Text(0.5, 1.03, 'Model Comparison - Model Accuracy')

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Random forest Classifier score gives us the best accuracy of about 98% out of all models
